# %%
#pip install torch torchvision

# %%
import os
import torch
import torch.nn as nn 
from torch.autograd import Variable
from torch.utils.data import DataLoader
import torch.optim as opt
from torchvision import datasets, transforms, models
import torchvision
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd

# %%
def get_data_set():

    transform_train = transforms.Compose([
                    transforms.Resize((224,224)), 
                    #transforms.AutoAugment(transforms.AutoAugmentPolicy.CIFAR10),
                    transforms.RandomCrop((224, 224)),
                    transforms.ColorJitter(brightness=0.5),
                    transforms.RandomRotation(10),
                    transforms.RandomHorizontalFlip(),
                    transforms.ToTensor(),
                    transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
    

    transform_test = transforms.Compose([
        transforms.Resize((224,224)), 
        transforms.ToTensor(),
        transforms.Normalize((0.5, 0.5, 0.5), (0.5, 0.5, 0.5))
    ])
    
    train = datasets.CIFAR10(root='../data', train=True, download=True, transform=transform_train)
    test = datasets.CIFAR10(root='../data', train=False, download=True, transform=transform_test)

    
    return train, test

train, test = get_data_set()
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ../data/cifar-10-python.tar.gz to ../data
# Files already downloaded and verified

# %%
BATCH_SIZE = 100 #原本為8

train_loader = DataLoader(train, batch_size= BATCH_SIZE, shuffle=True, num_workers= 0)
test_loader = DataLoader(test, batch_size= BATCH_SIZE, shuffle=False, num_workers= 0)

# %%
train_loader.dataset,test_loader.dataset
# Out:
# (Dataset CIFAR10
#      Number of datapoints: 50000
#      Root location: ../data
#      Split: Train
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=None)
#                 RandomCrop(size=(224, 224), padding=None)
#                 ColorJitter(brightness=[0.5, 1.5], contrast=None, saturation=None, hue=None)
#                 RandomRotation(degrees=[-10.0, 10.0], interpolation=nearest, expand=False, fill=0)
#                 RandomHorizontalFlip(p=0.5)
#                 ToTensor()
#                 Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#             ), Dataset CIFAR10
#      Number of datapoints: 10000
#      Root location: ../data
#      Split: Test
#      StandardTransform
#  Transform: Compose(
#                 Resize(size=(224, 224), interpolation=bilinear, max_size=None, antialias=None)
#                 ToTensor()
#                 Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#             ))

# %%
def imshow(img):
    img = img / 2 + 0.5
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))
    plt.show()

    
# get some random training images
dataiter = iter(train_loader)
images, labels = next(dataiter)

imshow(torchvision.utils.make_grid(images))

# %%
classes = ('plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck')

# %% [markdown]
# # Ensemble Model

# %%
model_vgg16=models.vgg16(weights="DEFAULT")
model_resnet50=models.resnet50(weights="DEFAULT")
model_googlenet=models.googlenet(weights="DEFAULT")
# Out:
# Downloading: "https://download.pytorch.org/models/vgg16-397923af.pth" to /root/.cache/torch/hub/checkpoints/vgg16-397923af.pth
#   0%|          | 0.00/528M [00:00<?, ?B/s]
# Downloading: "https://download.pytorch.org/models/resnet50-11ad3fa6.pth" to /root/.cache/torch/hub/checkpoints/resnet50-11ad3fa6.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]
# Downloading: "https://download.pytorch.org/models/googlenet-1378be20.pth" to /root/.cache/torch/hub/checkpoints/googlenet-1378be20.pth
#   0%|          | 0.00/49.7M [00:00<?, ?B/s]

# %%
for param in model_vgg16.parameters():
  param.requires_grad=False
for param in model_resnet50.parameters():
  param.requires_grad=False
for param in model_googlenet.parameters():
  param.requires_grad=False

# %%
model_vgg16.classifier=nn.Sequential(
     nn.Linear(in_features=25088, out_features=4096, bias=True),
     nn.ReLU(inplace=True),
     nn.Dropout(p=0.5, inplace=False),
     nn.Linear(in_features=4096, out_features=4096, bias=True),
     nn.ReLU(inplace=True),
     nn.Dropout(p=0.5, inplace=False),
     nn.Linear(in_features=4096, out_features=10, bias=True),
)
model_resnet50.fc=nn.Sequential(
     nn.Linear(in_features=2048, out_features=1024, bias=True),
     nn.ReLU(inplace=True),
     nn.Dropout(p=0.5, inplace=False),
     nn.Linear(in_features=1024, out_features=256, bias=True),
     nn.ReLU(inplace=True),
     nn.Dropout(p=0.5, inplace=False),
     nn.Linear(in_features=256, out_features=10, bias=True),
)
model_googlenet.fc=nn.Sequential(
     nn.Linear(in_features=1024, out_features=256, bias=True),
     nn.ReLU(inplace=True),
     nn.Dropout(p=0.5, inplace=False),
     nn.Linear(in_features=256, out_features=10, bias=True),
)

# %%
#要嘗試的組合: 1)accuracy 2)1/3 3)paper
wv = 85.73
wr = 76.60
wg = 74.13

# %%
weight_vgg16 = wv/(wv+wr+wg)
weight_resnet50 = wr/(wv+wr+wg)
weight_googlenet = wg/(wv+wr+wg)

# %%
model_vgg16=model_vgg16.cuda()
model_resnet50=model_resnet50.cuda()
model_googlenet=model_googlenet.cuda()

# %%
loss_fn=nn.CrossEntropyLoss()
optimizerV = opt.Adam(model_vgg16.classifier.parameters(), lr=1e-4)
lr_schedulerV = opt.lr_scheduler.ReduceLROnPlateau(optimizerV, factor=0.1, patience=3, verbose=True)

optimizerR=opt.Adam(model_resnet50.fc.parameters(),lr=0.0001)
optimizerG=opt.Adam(model_googlenet.fc.parameters(),lr=0.0005)

# %%
epoch_n=10

# %%
lossV_list = []
lossR_list = []
lossG_list = []
accu_list = []

for epoch in range(1, epoch_n+1):
  total_loss_vgg16 = 0.0
  total_loss_resnet50 = 0.0
  total_loss_googlenet = 0.0
  total_correct=0
  batch_num = 0

  for batch, (images,labels) in enumerate(train_loader,1):
    model_vgg16.train()
    
    images=Variable(images.cuda())
    labels=Variable(labels.cuda())

    y_pred_vgg16=model_vgg16(images)
    y_pred_resnet50=model_resnet50(images)
    y_pred_googlenet=model_googlenet(images)

    y_pred_e = (weight_vgg16*y_pred_vgg16)+(weight_resnet50*y_pred_resnet50)+(weight_googlenet*y_pred_googlenet)
    _,pred = torch.max(y_pred_e, 1)

    optimizerV.zero_grad()
    optimizerR.zero_grad()
    optimizerG.zero_grad()

    loss_vgg16=loss_fn(y_pred_vgg16,labels)
    loss_vgg16.backward()

    loss_resnet50=loss_fn(y_pred_resnet50,labels)
    loss_resnet50.backward()

    loss_googlenet=loss_fn(y_pred_googlenet,labels)
    loss_googlenet.backward()

    optimizerV.step()
    optimizerR.step()
    optimizerG.step()

    total_loss_vgg16 += loss_vgg16.data
    total_loss_resnet50 += loss_resnet50.data
    total_loss_googlenet += loss_googlenet.data

    total_correct+=torch.sum(pred==labels.data)
    if batch%100==0:
      print("epoch:%d, batch:%d, loss_vgg16:%.4f, loss_resnet50:%.4f, loss_googlenet:%.4f, accuracy:%.4f"
                            %(epoch,batch,(total_loss_vgg16/batch),(total_loss_resnet50/batch),(total_loss_googlenet/batch),(total_correct/batch)))
      lossV_list.append(total_loss_vgg16/batch)
      lossR_list.append(total_loss_resnet50/batch)
      lossG_list.append(total_loss_googlenet/batch)
      accu_list.append(total_correct/batch)
      batch_num += 1

      lr_schedulerV.step(total_loss_vgg16/batch)
# Out:
# epoch:1, batch:100, loss_vgg16:1.2339, loss_resnet50:2.0311, loss_googlenet:1.7377, accuracy:59.8400
# epoch:1, batch:200, loss_vgg16:1.0238, loss_resnet50:1.6612, loss_googlenet:1.4722, accuracy:68.4250
# epoch:1, batch:300, loss_vgg16:0.9333, loss_resnet50:1.4601, loss_googlenet:1.3452, accuracy:72.0667
# epoch:1, batch:400, loss_vgg16:0.8777, loss_resnet50:1.3280, loss_googlenet:1.2651, accuracy:74.2800
# epoch:1, batch:500, loss_vgg16:0.8384, loss_resnet50:1.2359, loss_googlenet:1.2077, accuracy:75.9100
# epoch:2, batch:100, loss_vgg16:0.6265, loss_resnet50:0.8217, loss_googlenet:0.9386, accuracy:83.5500
# epoch:2, batch:200, loss_vgg16:0.6183, loss_resnet50:0.8108, loss_googlenet:0.9445, accuracy:83.8750
# epoch:2, batch:300, loss_vgg16:0.6158, loss_resnet50:0.7974, loss_googlenet:0.9412, accuracy:83.9400
# epoch:2, batch:400, loss_vgg16:0.6138, loss_resnet50:0.7884, loss_googlenet:0.9393, accuracy:84.0375
# epoch:2, batch:500, loss_vgg16:0.6074, loss_resnet50:0.7755, loss_googlenet:0.9364, accuracy:84.2640
# epoch:3, batch:100, loss_vgg16:0.5593, loss_resnet50:0.7209, loss_googlenet:0.9109, accuracy:85.6100
# epoch:3, batch:200, loss_vgg16:0.5586, loss_resnet50:0.7075, loss_googlenet:0.9085, accuracy:85.7350
# epoch:3, batch:300, loss_vgg16:0.5544, loss_resnet50:0.7051, loss_googlenet:0.9057, accuracy:85.7900
# epoch:3, batch:400, loss_vgg16:0.5549, loss_resnet50:0.7021, loss_googlenet:0.9054, accuracy:85.7800
# epoch:3, batch:500, loss_vgg16:0.5503, loss_resnet50:0.6966, loss_googlenet:0.8984, accuracy:85.9940
# epoch:4, batch:100, loss_vgg16:0.5238, loss_resnet50:0.6599, loss_googlenet:0.8882, accuracy:86.8300
# epoch:4, batch:200, loss_vgg16:0.5173, loss_resnet50:0.6711, loss_googlenet:0.8855, accuracy:86.7150
# epoch:4, batch:300, loss_vgg16:0.5163, loss_resnet50:0.6723, loss_googlenet:0.8868, accuracy:86.5633
# epoch:4, batch:400, loss_vgg16:0.5133, loss_resnet50:0.6677, loss_googlenet:0.8803, accuracy:86.7625
# epoch:4, batch:500, loss_vgg16:0.5142, loss_resnet50:0.6662, loss_googlenet:0.8817, accuracy:86.7320
# epoch:5, batch:100, loss_vgg16:0.4864, loss_resnet50:0.6586, loss_googlenet:0.8654, accuracy:87.8100
# epoch:5, batch:200, loss_vgg16:0.4837, loss_resnet50:0.6429, loss_googlenet:0.8646, accuracy:87.8050
# epoch:5, batch:300, loss_vgg16:0.4870, loss_resnet50:0.6423, loss_googlenet:0.8744, accuracy:87.4800
# epoch:5, batch:400, loss_vgg16:0.4877, loss_resnet50:0.6469, loss_googlenet:0.8704, accuracy:87.5000
# epoch:5, batch:500, loss_vgg16:0.4863, loss_resnet50:0.6416, loss_googlenet:0.8651, accuracy:87.6820
# epoch:6, batch:100, loss_vgg16:0.4557, loss_resnet50:0.6059, loss_googlenet:0.8644, accuracy:88.5200
# epoch:6, batch:200, loss_vgg16:0.4551, loss_resnet50:0.6153, loss_googlenet:0.8623, accuracy:88.6500
# epoch:6, batch:300, loss_vgg16:0.4590, loss_resnet50:0.6166, loss_googlenet:0.8665, accuracy:88.3233
# epoch:6, batch:400, loss_vgg16:0.4583, loss_resnet50:0.6203, loss_googlenet:0.8615, accuracy:88.2650
# epoch:6, batch:500, loss_vgg16:0.4619, loss_resnet50:0.6188, loss_googlenet:0.8627, accuracy:88.2140
# epoch:7, batch:100, loss_vgg16:0.4309, loss_resnet50:0.5870, loss_googlenet:0.8560, accuracy:89.0400
# epoch:7, batch:200, loss_vgg16:0.4382, loss_resnet50:0.5994, loss_googlenet:0.8558, accuracy:88.7900
# epoch:7, batch:300, loss_vgg16:0.4436, loss_resnet50:0.6019, loss_googlenet:0.8564, accuracy:88.7367
# epoch:7, batch:400, loss_vgg16:0.4397, loss_resnet50:0.6022, loss_googlenet:0.8587, accuracy:88.7325
# epoch:7, batch:500, loss_vgg16:0.4418, loss_resnet50:0.6005, loss_googlenet:0.8551, accuracy:88.7260
# Epoch 00035: reducing learning rate of group 0 to 1.0000e-05.
# epoch:8, batch:100, loss_vgg16:0.3915, loss_resnet50:0.5953, loss_googlenet:0.8675, accuracy:89.6400
# epoch:8, batch:200, loss_vgg16:0.3822, loss_resnet50:0.5933, loss_googlenet:0.8560, accuracy:89.7650
# epoch:8, batch:300, loss_vgg16:0.3832, loss_resnet50:0.5924, loss_googlenet:0.8535, accuracy:89.6700
# epoch:8, batch:400, loss_vgg16:0.3761, loss_resnet50:0.5891, loss_googlenet:0.8527, accuracy:89.7575
# epoch:8, batch:500, loss_vgg16:0.3725, loss_resnet50:0.5902, loss_googlenet:0.8519, accuracy:89.7240
# epoch:9, batch:100, loss_vgg16:0.3596, loss_resnet50:0.5849, loss_googlenet:0.8382, accuracy:90.0600
# epoch:9, batch:200, loss_vgg16:0.3578, loss_resnet50:0.5835, loss_googlenet:0.8376, accuracy:90.1350
# epoch:9, batch:300, loss_vgg16:0.3580, loss_resnet50:0.5800, loss_googlenet:0.8375, accuracy:90.2067
# epoch:9, batch:400, loss_vgg16:0.3563, loss_resnet50:0.5813, loss_googlenet:0.8396, accuracy:90.0950
# epoch:9, batch:500, loss_vgg16:0.3526, loss_resnet50:0.5804, loss_googlenet:0.8410, accuracy:90.1200
# epoch:10, batch:100, loss_vgg16:0.3478, loss_resnet50:0.5921, loss_googlenet:0.8464, accuracy:89.4900
# epoch:10, batch:200, loss_vgg16:0.3384, loss_resnet50:0.5793, loss_googlenet:0.8384, accuracy:90.0150
# epoch:10, batch:300, loss_vgg16:0.3411, loss_resnet50:0.5797, loss_googlenet:0.8364, accuracy:90.1267
# epoch:10, batch:400, loss_vgg16:0.3403, loss_resnet50:0.5790, loss_googlenet:0.8389, accuracy:90.1000
# epoch:10, batch:500, loss_vgg16:0.3401, loss_resnet50:0.5761, loss_googlenet:0.8403, accuracy:90.1640

# %%
#如果圖畫出來很醜需要再微調
def draw(num_list, epochs, batch_num, y_label, title):
  x = range(len(num_list))
  plt.plot(x, num_list, '.-')

  labels = ['ep'+str(e)+'\n'+str(b)+'/'+str(batch_num) for e in range(1, epochs+1) for b in range(1, batch_num+1)]
  plt.xticks(ticks=x, labels=labels, rotation=0, fontsize=8) 

  plt.ylabel(y_label)
  plt.title(title)
  
  #plt.savefig(file_name)
  plt.show()

lossV_list = [i.cpu() for i in lossV_list]
draw(lossV_list, epoch_n, batch_num, 'Loss', 'VGG16')

accu_list = [i.cpu() for i in accu_list]
draw(accu_list, epoch_n, batch_num, 'Accuracy', 'Ensemble')

# %%
heatmap = pd.DataFrame(data=0, index=classes, columns=classes)

total_loss_vgg16 = 0.0
total_loss_resnet50 = 0.0
total_loss_googlenet = 0.0
total_correct=0

for batch, (images,labels) in enumerate(test_loader,1):
  model_vgg16.eval()

  images=Variable(images.cuda())
  labels=Variable(labels.cuda())

  y_pred_vgg16=model_vgg16(images)
  y_pred_resnet50=model_resnet50(images)
  y_pred_googlenet=model_googlenet(images)

  y_pred_e=(weight_vgg16*y_pred_vgg16)+(weight_resnet50*y_pred_resnet50)+(weight_googlenet*y_pred_googlenet)
  _,pred=torch.max(y_pred_e,1)

  for i in range(BATCH_SIZE):
    true_label = labels[i].item()
    pred_label = pred[i].item()
    heatmap.iloc[true_label, pred_label] += 1


  loss_vgg16=loss_fn(y_pred_vgg16,labels)

  loss_resnet50=loss_fn(y_pred_resnet50,labels)

  loss_googlenet=loss_fn(y_pred_googlenet,labels)


  total_loss_vgg16 += loss_vgg16.data
  total_loss_resnet50 += loss_resnet50.data
  total_loss_googlenet += loss_googlenet.data

  total_correct+=torch.sum(pred==labels.data)
  if batch%100==0:
    print(" batch:%d, loss_vgg16:%.4f, loss_resnet50:%.4f, loss_googlenet:%.4f, accuracy:%.4f"
                          %(batch,(total_loss_vgg16/batch),(total_loss_resnet50/batch),(total_loss_googlenet/batch),(total_correct/batch)))
# Out:
#  batch:100, loss_vgg16:0.3936, loss_resnet50:0.6630, loss_googlenet:0.7599, accuracy:90.0000

# %%
_, ax = plt.subplots(figsize=(10, 8))
ax = sns.heatmap(heatmap, annot=True, fmt="d", cmap="YlGnBu")
plt.show()
